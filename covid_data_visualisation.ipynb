# %% [markdown]
# ## EECS

# %% [markdown]
# ## Mohit Limba

# %% [markdown]
# ## 18147

# %% [markdown]
# ## Assingment3

# %%
# !pip install covid

# %%
from covid import Covid

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
covid = Covid()

# %%
covid.source
# Out:
# 'john_hopkins'

# %%
covid = Covid(source="john_hopkins")

# %%
covid.get_data()
# Out:
# [{'id': '182',
#   'country': 'US',
#   'confirmed': 45703978,
#   'active': None,
#   'deaths': 741231,
#   'recovered': None,
#   'latitude': 40.0,
#   'longitude': -100.0,
#   'last_update': 1635394928000},
#  {'id': '80',
#   'country': 'India',
#   'confirmed': 34215653,
#   'active': None,
#   'deaths': 455653,
#   'recovered': None,
#   'latitude': 20.593684,
#   'longitude': 78.96288,
#   'last_update': 1635394928000},
#  {'id': '24',
#   'country': 'Brazil',
#   'confirmed': 21766168,
#   'active': None,
#   'deaths': 606679,
#   'recovered': None,
#   'latitude': -14.235,
#   'longitude': -51.9253,
#   'last_update': 1635394928000},
#  {'id': '186',
#   'country': 'United Kingdom',
#   'confirmed': 8938965,
#   'active': None,
#   'deaths': 140462,
#   'recovered': None,
#   'latitude': 55.0,
#   'longitude': -3.0,
#   'last_update': 1635394928000},
#  {'id': '145',
#   'country': 'Russia',
#   'confirmed': 8220975,
#   'active': None,
#   'deaths': 229672,
# ...

# %%
covid = Covid(source="worldometers")

# %%
covid.get_data()
# Out:
# [{'country': 'North America',
#   'total_cases': 55982988,
#   'confirmed': 55982988,
#   'new_cases': 5029,
#   'deaths': 1142080,
#   'new_deaths': 394,
#   'recovered': 44603536,
#   'active': 10237372,
#   'active_cases': 10237372,
#   'critical': 20048,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'Asia',
#   'total_cases': 78993227,
#   'confirmed': 78993227,
#   'new_cases': 16435,
#   'deaths': 1164863,
#   'new_deaths': 141,
#   'recovered': 76032144,
#   'active': 1796220,
#   'active_cases': 1796220,
#   'critical': 27237,
#   'total_tests': 0,
#   'total_tests_per_million': Decimal('0'),
#   'total_cases_per_million': Decimal('0'),
#   'total_deaths_per_million': Decimal('0'),
#   'population': Decimal('0')},
#  {'country': 'South America',
#   'total_cases': 38343935,
#   'confirmed': 38343935,
# ...

# %%
covid.source
# Out:
# 'worldometers'

# %%
covid.get_status_by_country_name("india")
# Out:
# {'country': 'India',
#  'total_cases': 34231809,
#  'confirmed': 34231809,
#  'new_cases': 602,
#  'deaths': 456418,
#  'new_deaths': 0,
#  'recovered': 33614434,
#  'active': 160957,
#  'active_cases': 160957,
#  'critical': 8944,
#  'total_tests': 604498405,
#  'total_tests_per_million': Decimal('0'),
#  'total_cases_per_million': Decimal('24488'),
#  'total_deaths_per_million': Decimal('327'),
#  'population': Decimal('1397902013')}

# %%
 covid.list_countries()
# Out:
# ['north america',
#  'asia',
#  'south america',
#  'europe',
#  'africa',
#  'oceania',
#  '',
#  'world',
#  'usa',
#  'india',
#  'brazil',
#  'uk',
#  'russia',
#  'turkey',
#  'france',
#  'iran',
#  'argentina',
#  'spain',
#  'colombia',
#  'italy',
#  'germany',
#  'indonesia',
#  'mexico',
#  'poland',
#  'south africa',
#  'ukraine',
#  'philippines',
#  'malaysia',
#  'peru',
#  'netherlands',
#  'iraq',
#  'thailand',
#  'czechia',
#  'japan',
#  'canada',
#  'chile',
#  'romania',
#  'bangladesh',
#  'belgium',
#  'israel',
#  'pakistan',
#  'sweden',
#  'serbia',
#  'portugal',
#  'cuba',
#  'morocco',
#  'kazakhstan',
#  'vietnam',
#  'switzerland',
#  'jordan',
#  'hungary',
#  'nepal',
#  'austria',
#  'uae',
#  'greece',
#  'tunisia',
#  'georgia',
#  'lebanon',
#  'guatemala',
#  'belarus',
#  'bulgaria',
#  'costa rica',
#  'saudi arabia',
#  'sri lanka',
#  'azerbaijan',
#  'ecuador',
#  'bolivia',
#  'myanmar',
#  'panama',
#  'slovakia',
#  'paraguay',
# ...

# %%
covid.get_total_active_cases()
# Out:
# 18010418

# %%
covid.get_total_confirmed_cases()
# Out:
# 245793895

# %%
covid.get_total_recovered()
# Out:
# 222795567

# %%
covid.get_total_deaths()
# Out:
# 4987910

# %%
df_covid = pd.DataFrame(covid.get_data())

# %%
df_covid
# Out:
#               country  total_cases  confirmed  new_cases   deaths  new_deaths  \
# 0       North America     55982988   55982988       5029  1142080         394
# 1                Asia     78993227   78993227      16435  1164863         141
# 2       South America     38343935   38343935        707  1168929           4
# 3              Europe     63611542   63611542       8771  1290239          32
# 4              Africa      8557584    8557584          0   218145           0
# ..                ...          ...        ...        ...      ...         ...
# 226  Marshall Islands            4          4          0        0           0
# 227             Samoa            3          3          0        0           0
# 228      Saint Helena            2          2          0        0           0
# 229        Micronesia            1          1          0        0           0
# 230             China        96938      96938         39     4636           0
#
# ...

# %%
df_covid_continents=df_covid.head(n=6)
df_covid_continents
# Out:
#          country  total_cases  confirmed  new_cases   deaths  new_deaths  \
# 0  North America     55982988   55982988       5029  1142080         394
# 1           Asia     78993227   78993227      16435  1164863         141
# 2  South America     38343935   38343935        707  1168929           4
# 3         Europe     63611542   63611542       8771  1290239          32
# 4         Africa      8557584    8557584          0   218145           0
# 5        Oceania       303898     303898       2231     3639          27
#
#    recovered    active  active_cases  critical  total_tests  \
# 0   44603536  10237372      10237372     20048            0
# 1   76032144   1796220       1796220     27237            0
# 2   36513911    661095        661095     12393            0
# 3   57504558   4816745       4816745     12839            0
# 4    7894298    445141        445141      2469            0
# 5     246414     53845         53845       326            0
#
# ...

# %%
continents=np.array(df_covid_continents['country'])
continents
# Out:
# array(['North America', 'Asia', 'South America', 'Europe', 'Africa',
#        'Oceania'], dtype=object)

# %%
df_covid_continents.plot(x='country',y=['total_cases','active','recovered','deaths'],kind='bar',color='brgk',figsize=(12,8))
plt.xlabel('country',fontsize=15)
plt.ylabel('No. of cases',fontsize=15)
plt.show()

# %%
df_covid_world=df_covid.loc[7]
df_covid_world
# Out:
# country                         World
# total_cases                 245793895
# confirmed                   245793895
# new_cases                       33173
# deaths                        4987910
# new_deaths                        598
# recovered                   222795567
# active                       18010418
# active_cases                 18010418
# critical                        75312
# total_tests                         0
# total_tests_per_million             0
# total_cases_per_million         31533
# total_deaths_per_million        639.9
# population                          0
# Name: 7, dtype: object

# %%
df_covid_countries = df_covid.loc[range(8,231)]
df_covid_countries
# Out:
#               country  total_cases  confirmed  new_cases  deaths  new_deaths  \
# 8                 USA     46597003   46597003          0  761856           0
# 9               India     34231809   34231809        602  456418           0
# 10             Brazil     21766168   21766168          0  606726           0
# 11                 UK      8897149    8897149          0  140041           0
# 12             Russia      8352601    8352601          0  233898           0
# ..                ...          ...        ...        ...     ...         ...
# 226  Marshall Islands            4          4          0       0           0
# 227             Samoa            3          3          0       0           0
# 228      Saint Helena            2          2          0       0           0
# 229        Micronesia            1          1          0       0           0
# 230             China        96938      96938         39    4636           0
#
# ...

# %%
df_covid_countries['total_cases'].max()
# Out:
# 46597003

# %%
world_cases=[df_covid_world['active_cases'],df_covid_world['deaths'],df_covid_world['recovered']]
                
plt.pie(world_cases, labels=['Active','Deaths','Recovered'],colors='rbg',center=(0,100) ,radius=1.2, startangle=15)
plt.title('World Cases')
plt.legend(title='world Cases',bbox_to_anchor=(1.2,1.0))
plt.show()

# %%
plt.bar( 'confirmed',df_covid_world['confirmed'],color='b',label='Confirmed')
plt.bar( 'Active',df_covid_world['active'],color='r',label='Active')
plt.bar( 'Recovered',df_covid_world['recovered'],color='g',label='Recovered')
plt.bar( 'Deaths',df_covid_world['deaths'],color='k',label='Deaths')       
plt.title('World Cases')
plt.legend(title='world Cases',bbox_to_anchor=(1.4,1.0))
plt.ylabel('Total Cases',Fontsize=15)
plt.show()

# %%
df_covid_countries_sorted_by_confirmed = df_covid_countries.sort_values(by='confirmed', ascending=False)

# %%
df_covid_countries_sorted_by_confirmed
# Out:
#               country  total_cases  confirmed  new_cases  deaths  new_deaths  \
# 8                 USA     46597003   46597003          0  761856           0
# 9               India     34231809   34231809        602  456418           0
# 10             Brazil     21766168   21766168          0  606726           0
# 11                 UK      8897149    8897149          0  140041           0
# 12             Russia      8352601    8352601          0  233898           0
# ..                ...          ...        ...        ...     ...         ...
# 225           Vanuatu            6          6          0       1           0
# 226  Marshall Islands            4          4          0       0           0
# 227             Samoa            3          3          0       0           0
# 228      Saint Helena            2          2          0       0           0
# 229        Micronesia            1          1          0       0           0
#
# ...

# %%
df_covid_countries_sorted_by_confirmed[['country','confirmed']]
# Out:
#               country  confirmed
# 8                 USA   46597003
# 9               India   34231809
# 10             Brazil   21766168
# 11                 UK    8897149
# 12             Russia    8352601
# ..                ...        ...
# 225           Vanuatu          6
# 226  Marshall Islands          4
# 227             Samoa          3
# 228      Saint Helena          2
# 229        Micronesia          1
#
# [223 rows x 2 columns]

# %%
plt.figure(figsize=(10,8))
plt.bar(df_covid_countries_sorted_by_confirmed['country'].head(n=10),
        df_covid_countries_sorted_by_confirmed['confirmed'].head(n=10),width=0.8)

plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Confirmed cases',fontsize=15)
plt.title('Top 10 Countries affected by COVID-19',fontsize='20')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(df_covid_countries_sorted_by_confirmed['country'].head(n=10),
        df_covid_countries_sorted_by_confirmed['confirmed'].head(n=10))

plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Confirmed cases',fontsize=15)
plt.title('Top 10 Countries affected by COVID-19',fontsize='20')
plt.show()

# %%
df_covid_countries_sorted_by_active = df_covid_countries.sort_values(by='active', ascending=False)
df_covid_countries_sorted_by_active
# Out:
#                    country  total_cases  confirmed  new_cases  deaths  \
# 8                      USA     46597003   46597003          0  761856
# 11                      UK      8897149    8897149          0  140041
# 12                  Russia      8352601    8352601          0  233898
# 13                  Turkey      7936007    7936007          0   69769
# 25                 Ukraine      2825733    2825733          0   65628
# ..                     ...          ...        ...        ...     ...
# 221        Solomon Islands           20         20          0       0
# 220           Vatican City           27         27          0       0
# 28                    Peru      2198038    2198038          0  200149
# 215      Wallis and Futuna          445        445          0       7
# 219  Saint Pierre Miquelon           32         32          0       0
#
#      new_deaths  recovered   active  active_cases  critical  total_tests  \
# ...

# %%
plt.figure(figsize=(10,8))
plt.bar(df_covid_countries_sorted_by_active['country'].head(n=10),
        df_covid_countries_sorted_by_active['active'].head(n=10),width=0.8,color='r')

plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Active cases',fontsize=15)
plt.title('Top 10 Countries Having Most Active COVID-19 cases',fontsize='20')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(df_covid_countries_sorted_by_active['country'].head(n=10),
        df_covid_countries_sorted_by_active['active'].head(n=10),color='r')

plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Active cases',fontsize=15)
plt.title('Top 10 Countries Having Active COVID-19 cases',fontsize='20')
plt.show()

# %%
df_covid_countries_sorted_by_Deaths = df_covid_countries.sort_values(by='deaths', ascending=False)
df_covid_countries_sorted_by_Deaths
# Out:
#               country  total_cases  confirmed  new_cases  deaths  new_deaths  \
# 8                 USA     46597003   46597003          0  761856           0
# 10             Brazil     21766168   21766168          0  606726           0
# 9               India     34231809   34231809        602  456418           0
# 22             Mexico      3793783    3793783       4797  287274         386
# 12             Russia      8352601    8352601          0  233898           0
# ..                ...          ...        ...        ...     ...         ...
# 226  Marshall Islands            4          4          0       0           0
# 227             Samoa            3          3          0       0           0
# 228      Saint Helena            2          2          0       0           0
# 229        Micronesia            1          1          0       0           0
# 216             Macao           77         77          0       0           0
#
# ...

# %%
plt.figure(figsize=(10,8))
plt.bar(df_covid_countries_sorted_by_Deaths['country'].head(n=10),
        df_covid_countries_sorted_by_Deaths['deaths'].head(n=10),width=0.8,color='black')

plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('No. of Deaths ',fontsize=15)
plt.title('Top 10 Countries Having Most No. of Deaths Due to COVID-19',fontsize='20')
plt.show()

# %%
df_covid_countries_sorted_by_Recoveries = df_covid_countries.sort_values(by='recovered', ascending=False)
df_covid_countries_sorted_by_Recoveries
# Out:
#           country  total_cases  confirmed  new_cases  deaths  new_deaths  \
# 8             USA     46597003   46597003          0  761856           0
# 9           India     34231809   34231809        602  456418           0
# 10         Brazil     21766168   21766168          0  606726           0
# 13         Turkey      7936007    7936007          0   69769           0
# 12         Russia      8352601    8352601          0  233898           0
# ..            ...          ...        ...        ...     ...         ...
# 227         Samoa            3          3          0       0           0
# 228  Saint Helena            2          2          0       0           0
# 229    Micronesia            1          1          0       0           0
# 149      Tanzania        26154      26154          0     725           0
# 28           Peru      2198038    2198038          0  200149           0
#
#      recovered   active  active_cases  critical  total_tests  \
# ...

# %%
plt.figure(figsize=(10,8))
plt.bar(df_covid_countries_sorted_by_Recoveries['country'].head(n=10),
        df_covid_countries_sorted_by_Recoveries['recovered'].head(n=10),width=0.8,color='g')

plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('No. of Recoveries ',fontsize=15)
plt.title('Top 10 Countries Having Most No. of Recoveries from COVID-19',fontsize='20')
plt.show()

# %%
top_10_countries=df_covid_countries_sorted_by_confirmed.head(10)

# %%
top_10_countries.plot(x='country',y='confirmed',kind='line',figsize=(10,8))
plt.title('top 10')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(df_covid_countries_sorted_by_confirmed['country'].head(n=10),
        df_covid_countries_sorted_by_confirmed['confirmed'].head(n=10),'b',label='Confirmed')
plt.plot(df_covid_countries_sorted_by_confirmed['country'].head(n=10),
        df_covid_countries_sorted_by_confirmed['active'].head(n=10),'r',label='Active')
plt.plot(df_covid_countries_sorted_by_confirmed['country'].head(n=10),
        df_covid_countries_sorted_by_confirmed['recovered'].head(n=10),'g',label='Recovered')
plt.plot(df_covid_countries_sorted_by_confirmed['country'].head(n=10),
        df_covid_countries_sorted_by_confirmed['deaths'].head(n=10),'black',label='Deaths')
plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Total cases',fontsize=15)
plt.title('Top 10 Countries affected by COVID-19',fontsize='20')
plt.legend()
plt.show()

# %%
top_10_countries.plot(x='country',y=['confirmed','active','recovered','deaths'],kind='line',figsize=(10,8),color=)
plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Total cases',fontsize=15)
plt.title('Top 10 Countries affected by COVID-19',fontsize='20')
plt.legend()
plt.show()

# %%
top_10_countries.plot(x='country',y=['confirmed','active','recovered','deaths'],kind='bar',figsize=(12,8),color='brgk')
plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Total cases',fontsize=15)
plt.title('Top 10 Countries affected by COVID-19',fontsize='20')
plt.legend()
plt.show()

# %%
top_10_countries.plot.area(x='country',y=['confirmed','active','recovered','deaths'],figsize=(10,8))
plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Total cases',fontsize=15)
plt.title('Top 10 Countries affected by COVID-19',fontsize='20')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))

countries=np.array(top_10_countries['country'])


x1=np.arange(len(countries))                   
cases=['confirmed','active','recovered','deaths']
for i in cases:
    plt.scatter(x=x1,y=[top_10_countries[i]],label=i,s=[top_10_countries.loc[8,i]/100000] )
plt.xticks(x1,countries,rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Total cases',fontsize=15)
plt.title('Top 10 Countries affected by COVID-19',fontsize='20')
plt.legend()
plt.show()
